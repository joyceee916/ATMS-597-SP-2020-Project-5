# %% [markdown]
# <a href="https://colab.research.google.com/github/joyceee916/ATMS-597-SP-2020-Project-5/blob/master/Project5_Joyce_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages
# https://www.freecodecamp.org/news/how-to-combine-multiple-csv-files-with-8-lines-of-code-265183e0854/
import os 
import glob 
import pandas as pd

# %%
# Change directory 
os.chdir("/content/drive/My Drive/ATMS 597/Project5")

# %%
def csvNames():
    csv_prefix = 'df'
    csv_suffix = '.csv'
    years = []
    for year in range(2000, 2021):
        years.append(year)
    csv_names = [csv_prefix + str(year) + csv_suffix for year in years]
    return csv_names

csv_names = csvNames()

# %%
combined_csv = pd.concat([pd.read_csv(csv) for csv in csv_names], ignore_index=True)

# %%
combined_csv
# Out:
#        station_id  latitude  ...  eastward_wind  northward_wind
# 0            KGRB     44.48  ...       7.517541        2.736161
# 1            KGRB     44.48  ...       7.878462        1.389185
# 2            KGRB     44.48  ...       8.863270        1.562834
# 3            KGRB     44.48  ...       6.577848        2.394141
# 4            KGRB     44.48  ...       7.517541        2.736161
# ...           ...       ...  ...            ...             ...
# 162303       KGRB     44.48  ...      -4.446262      -12.216004
# 162304       KGRB     44.48  ...      -4.788282      -13.155697
# 162305       KGRB     44.48  ...      -6.500000      -11.258330
# 162306       KGRB     44.48  ...      -7.000000      -12.124356
# 162307       KGRB     44.48  ...      -8.999027      -10.724622
#
# [162308 rows x 28 columns]

# %%
combined_csv.to_csv('KGRB_precip.csv', index=False)
